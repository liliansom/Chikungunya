# %% [markdown]
# ## Importação dos Dados

# %%
import pandas as pd

# %% [markdown]
# ## Dicionário de Dados

# %%
# Criando dataframe dos municípios com casos de chikungunya na primeira semana
municipio = []
casos = []
for i in range(len(df)):
    if df.loc[df['SE01']] != 0:
        municipio.append(df.loc[i, 'município'])
        casos.append(df.loc[i, 'SE01'])
        
semana_1 = pd.DataFrame({'município': municipio, 'casos': casos})
display(semana_1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       2 municipio = []
#       3 casos = []
# ----> 4 for i in range(len(df)):
#       5     if df.loc[df['SE01']] != 0:
#       6         municipio.append(df.loc[i, 'município'])
#
# NameError: name 'df' is not defined

# %%
semanas = df.iloc[:, 7:-1]
semanas.columns
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 semanas = df.iloc[:, 7:-1]
#       2 semanas.columns
#
# NameError: name 'df' is not defined

# %%
marilia = df.iloc[:, 7:-1]
